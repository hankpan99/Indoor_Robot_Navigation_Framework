# %%
import sys
import cv2
import math
import glob
import json
import open3d as o3d
import magnum as mn
import numpy as np
from PIL import Image
import habitat_sim
from habitat_sim.utils import common as utils
from habitat_sim.utils.common import d3_40_colors_rgb
import quaternion
from scipy.spatial import distance
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# sys.path.append('/mnt/sdb/hank/habitat-lab')
# from habitat.core.simulator import Simulator

dataset_name = "demo"

# %%
def transform_rgb_bgr(image):
    return image[:, :, [2, 1, 0]]

def transform_depth(image):
    depth_img = (image / 10 * 255).astype(np.uint8)
    return depth_img

def transform_semantic(semantic_obs):
    semantic_img = Image.new("P", (semantic_obs.shape[1], semantic_obs.shape[0]))
    semantic_img.putpalette(d3_40_colors_rgb.flatten())
    semantic_img.putdata((semantic_obs.flatten() % 40).astype(np.uint8))
    semantic_img = semantic_img.convert("RGB")
    semantic_img = cv2.cvtColor(np.asarray(semantic_img), cv2.COLOR_RGB2BGR)
    return semantic_img

# %%
scene_path = f"../../../../../data/scene_datasets/apartment_0/habitat/mesh_semantic.ply"

sim_settings = {
    "scene": scene_path,  # Scene path
    "default_agent": 0,  # Index of the default agent
    "sensor_height": 1.5,  # Height of sensors in meters, relative to the agent
    "width": 512,  # Spatial resolution of the observations
    "height": 512,
    "sensor_pitch": 0,  # sensor pitch (x rotation in rads)
}

foward_per_step = 0.01
rotation_per_step = 1

def make_simple_cfg(settings, foward_per_step, rotation_per_step):
    # simulator backend
    sim_cfg = habitat_sim.SimulatorConfiguration()
    sim_cfg.scene_id = settings["scene"]
    # agent
    agent_cfg = habitat_sim.agent.AgentConfiguration()

    # In the 1st example, we attach only one sensor,
    # a RGB visual sensor, to the agent
    rgb_sensor_spec = habitat_sim.CameraSensorSpec()
    rgb_sensor_spec.uuid = "color_sensor"
    rgb_sensor_spec.sensor_type = habitat_sim.SensorType.COLOR
    rgb_sensor_spec.resolution = [settings["height"], settings["width"]]
    rgb_sensor_spec.position = [0.0, settings["sensor_height"], 0.0]
    rgb_sensor_spec.orientation = [
        settings["sensor_pitch"],
        0.0,
        0.0,
    ]
    rgb_sensor_spec.sensor_subtype = habitat_sim.SensorSubType.PINHOLE

    #depth snesor
    depth_sensor_spec = habitat_sim.CameraSensorSpec()
    depth_sensor_spec.uuid = "depth_sensor"
    depth_sensor_spec.sensor_type = habitat_sim.SensorType.DEPTH
    depth_sensor_spec.resolution = [settings["height"], settings["width"]]
    depth_sensor_spec.position = [0.0, settings["sensor_height"], 0.0]
    depth_sensor_spec.orientation = [
        settings["sensor_pitch"],
        0.0,
        0.0,
    ]
    depth_sensor_spec.sensor_subtype = habitat_sim.SensorSubType.PINHOLE

    #semantic snesor
    semantic_sensor_spec = habitat_sim.CameraSensorSpec()
    semantic_sensor_spec.uuid = "semantic_sensor"
    semantic_sensor_spec.sensor_type = habitat_sim.SensorType.SEMANTIC
    semantic_sensor_spec.resolution = [settings["height"], settings["width"]]
    semantic_sensor_spec.position = [0.0, settings["sensor_height"], 0.0]
    semantic_sensor_spec.orientation = [
        settings["sensor_pitch"],
        0.0,
        0.0,
    ]
    semantic_sensor_spec.sensor_subtype = habitat_sim.SensorSubType.PINHOLE

    agent_cfg.sensor_specifications = [rgb_sensor_spec, depth_sensor_spec, semantic_sensor_spec]

    # Here you can specify the amount of displacement in a forward action and the turn angle
    
    #agent_cfg.sensor_specifications = sensor_specs
    agent_cfg.action_space = {
        "move_forward": habitat_sim.agent.ActionSpec(
            "move_forward", habitat_sim.agent.ActuationSpec(amount = foward_per_step)
        ),
        "turn_left": habitat_sim.agent.ActionSpec(
            "turn_left", habitat_sim.agent.ActuationSpec(amount = rotation_per_step)
        ),
        "turn_right": habitat_sim.agent.ActionSpec(
            "turn_right", habitat_sim.agent.ActuationSpec(amount = rotation_per_step)
        ),
    }

    return habitat_sim.Configuration(sim_cfg, [agent_cfg])

cfg = make_simple_cfg(sim_settings, foward_per_step, rotation_per_step)
sim = habitat_sim.Simulator(cfg)
agent = sim.initialize_agent(sim_settings["default_agent"])
# Out:
# I0910 04:34:10.547018 25968 simulator.py:221] Loaded navmesh ../../../../../data/scene_datasets/apartment_0/habitat/mesh_semantic.navmesh
# INFO - 2022-09-10 04:34:10,547 - simulator - I0910 04:34:10.547018 25968 simulator.py:221] Loaded navmesh ../../../../../data/scene_datasets/apartment_0/habitat/mesh_semantic.navmesh

# %%
def load_path_points(filename = dataset_name):
    tmp = np.load(f'./data/navigate_path/{filename}/path.npy')
    path_points = np.zeros((tmp.shape[0], 3))
    path_points[:, 0] = tmp[:, 1]
    path_points[:, 1] = -1.3747652
    path_points[:, 2] = tmp[:, 0]
    print('total path points: ', path_points.shape[0])

    return path_points

path_points = load_path_points()
# Out:
# total path points:  3

# %%
with open(f"../../../../../data/scene_datasets/apartment_0/habitat/info_semantic.json", "r") as f:
    annotations = json.load(f)

instance_id_to_semantic_label_id = np.array(annotations["id_to_label"])

def navigateAndSee(cnt, action = "", filename = dataset_name, target_id = 29, instance_id_to_semantic_label_id = instance_id_to_semantic_label_id):
    observations = sim.step(action)

    # cv2.imshow("RGB", transform_rgb_bgr(observations["color_sensor"]))
    # cv2.imshow("depth", transform_depth(observations["depth_sensor"]))
    # cv2.imshow("semantic", transform_semantic(observations["semantic_sensor"]))

    rgb_img = transform_rgb_bgr(observations["color_sensor"])                                                                                           
    red_mask = np.copy(rgb_img)

    idx = np.where(observations["semantic_sensor"] == 4)
    
    if idx[0].size != 0:
        for i, j in zip(idx[0], idx[1]):
            red_mask[i][j] = np.array([0, 0, 255])

        rgb_img = cv2.addWeighted(red_mask, 0.3, rgb_img, 0.7, 0, red_mask)

    cv2.imwrite(f'./trajectory/{filename}/rgb/{str(cnt).zfill(5)}.png', rgb_img)

    agent_state = agent.get_state()
    # sensor_state = agent_state.sensor_states['color_sensor']
    # print("camera pose: x y z rw rx ry rz")
    # print(sensor_state.position[0],sensor_state.position[1],sensor_state.position[2], sensor_state.rotation.w, sensor_state.rotation.x, sensor_state.rotation.y, sensor_state.rotation.z)

    return agent_state.position, agent_state.position

# Set agent state
agent_state = habitat_sim.AgentState()
agent_state.position = path_points[0]

tangent_orientation_matrix = mn.Matrix4.look_at(path_points[0], path_points[1], np.array([0.0, 1.0, 0.0]))
tangent_orientation_q = mn.Quaternion.from_matrix(tangent_orientation_matrix.rotation())
agent_state.rotation = utils.quat_from_magnum(tangent_orientation_q)
agent.set_state(agent_state)

# %%
def is_valid(start_point, end_point, sim):
    vector = (end_point - start_point)/5

    tmp_points = []
    for i in range(10):
        tmp_points.append(start_point + i*vector)
    tmp_points.append(end_point)

    for i in tmp_points:
        if not sim.pathfinder.is_navigable(i):
            return False

    return True      

cnt = 0
for i in range(1, len(path_points)):
    print(f'reach point {i-1}')

    agent_state = agent.get_state()
    sensor_state = agent_state.sensor_states['color_sensor']

    cur_pos = sensor_state.position
    cur_ori = sensor_state.rotation
    tar_pos = path_points[i]

    if i > 1:
        tar_orientation_matrix = np.array(mn.Matrix4.look_at(cur_pos, tar_pos, np.array([0.0, 1.0, 0.0])).rotation())
        cur_orientation_matrix = quaternion.as_rotation_matrix(cur_ori)
        relative_ori_matrix = np.dot(tar_orientation_matrix[0:3, 0:3], cur_orientation_matrix[0:3, 0:3].T)
        agl_diff = np.arcsin(relative_ori_matrix[0][2])/(np.pi)*180

        if agl_diff > 0:
            steps = math.floor(agl_diff/rotation_per_step)

            for j in range(steps):
                action = "turn_left"
                print(f'step{cnt}: action = {action}')
                cur_pos, cur_ori = navigateAndSee(cnt, action)
                cnt += 1
        else:
            steps = math.floor(abs(agl_diff)/rotation_per_step)

            for j in range(steps):
                action = "turn_right"
                print(f'step{cnt}: action = {action}')
                cur_pos, cur_ori = navigateAndSee(cnt, action)
                cnt += 1
    
    dst_diff = distance.euclidean(cur_pos, tar_pos)
    steps = math.floor(dst_diff/foward_per_step)
    unit_vector = (path_points[i] - path_points[i-1])/dst_diff
    
    for j in range(steps):
        if (i == len(path_points) - 1) and (distance.euclidean(cur_pos, tar_pos) < 1):
            break

        action = "move_forward"
        print(f'step{cnt}: action = {action}')
        cur_pos, cur_ori = navigateAndSee(cnt, action)
        cnt += 1

        '''
        test_point = list(path_points[i-1] + unit_vector*foward_per_step)

        if is_valid(cur_pos, test_point, sim):
        #if sim.pathfinder.is_navigable(test_point):
            action = "move_forward"
            print(f'step{cnt}: action = {action}')
            cur_pos, cur_ori = navigateAndSee(cnt, action)
            cnt += 1
        else:
            # sample_points = Simulator.sample_navigable_point()
            # if(distance.euclidean(sample_points, cur_pos) < foward_per_step):
            
            print('early turn')
            break
        '''
    print()
# Out:
# reach point 0
# step0: action = move_forward
# step1: action = move_forward
# step2: action = move_forward
# step3: action = move_forward
# step4: action = move_forward
# step5: action = move_forward
# step6: action = move_forward
# step7: action = move_forward
# step8: action = move_forward
# step9: action = move_forward
# step10: action = move_forward
# step11: action = move_forward
# step12: action = move_forward
# step13: action = move_forward
# step14: action = move_forward
# step15: action = move_forward
# step16: action = move_forward
# step17: action = move_forward
# step18: action = move_forward
# step19: action = move_forward
# step20: action = move_forward
# step21: action = move_forward
# step22: action = move_forward
# step23: action = move_forward
# step24: action = move_forward
# step25: action = move_forward
# step26: action = move_forward
# step27: action = move_forward
# step28: action = move_forward
# step29: action = move_forward
# step30: action = move_forward
# step31: action = move_forward
# step32: action = move_forward
# step33: action = move_forward
# step34: action = move_forward
# step35: action = move_forward
# step36: action = move_forward
# step37: action = move_forward
# step38: action = move_forward
# step39: action = move_forward
# step40: action = move_forward
# step41: action = move_forward
# step42: action = move_forward
# step43: action = move_forward
# step44: action = move_forward
# step45: action = move_forward
# step46: action = move_forward
# step47: action = move_forward
# step48: action = move_forward
# step49: action = move_forward
# step50: action = move_forward
# step51: action = move_forward
# step52: action = move_forward
# step53: action = move_forward
# step54: action = move_forward
# step55: action = move_forward
# step56: action = move_forward
# step57: action = move_forward
# step58: action = move_forward
# step59: action = move_forward
# step60: action = move_forward
# step61: action = move_forward
# step62: action = move_forward
# step63: action = move_forward
# step64: action = move_forward
# step65: action = move_forward
# step66: action = move_forward
# step67: action = move_forward
# step68: action = move_forward
# step69: action = move_forward
# step70: action = move_forward
# step71: action = move_forward
# step72: action = move_forward
# step73: action = move_forward
# step74: action = move_forward
# step75: action = move_forward
# step76: action = move_forward
# step77: action = move_forward
# step78: action = move_forward
# step79: action = move_forward
# step80: action = move_forward
# step81: action = move_forward
# step82: action = move_forward
# step83: action = move_forward
# step84: action = move_forward
# step85: action = move_forward
# step86: action = move_forward
# step87: action = move_forward
# step88: action = move_forward
# step89: action = move_forward
# step90: action = move_forward
# step91: action = move_forward
# step92: action = move_forward
# step93: action = move_forward
# step94: action = move_forward
# step95: action = move_forward
# step96: action = move_forward
# step97: action = move_forward
# step98: action = move_forward
# step99: action = move_forward
# step100: action = move_forward
# step101: action = move_forward
# step102: action = move_forward
# step103: action = move_forward
# step104: action = move_forward
# step105: action = move_forward
# step106: action = move_forward
# step107: action = move_forward
# step108: action = move_forward
# step109: action = move_forward
# step110: action = move_forward
# step111: action = move_forward
# step112: action = move_forward
# step113: action = move_forward
# step114: action = move_forward
# step115: action = move_forward
# step116: action = move_forward
# step117: action = move_forward
# step118: action = move_forward
# step119: action = move_forward
# step120: action = move_forward
# step121: action = move_forward
# step122: action = move_forward
# step123: action = move_forward
# step124: action = move_forward
# step125: action = move_forward
# step126: action = move_forward
# step127: action = move_forward
# step128: action = move_forward
# step129: action = move_forward
# step130: action = move_forward
# step131: action = move_forward
# step132: action = move_forward
# step133: action = move_forward
# step134: action = move_forward
# step135: action = move_forward
# step136: action = move_forward
# step137: action = move_forward
# step138: action = move_forward
# step139: action = move_forward
# step140: action = move_forward
# step141: action = move_forward
# step142: action = move_forward
# step143: action = move_forward
# step144: action = move_forward
# step145: action = move_forward
# step146: action = move_forward
# step147: action = move_forward
# step148: action = move_forward
# step149: action = move_forward
# step150: action = move_forward
# step151: action = move_forward
# step152: action = move_forward
# step153: action = move_forward
# step154: action = move_forward
# step155: action = move_forward
# step156: action = move_forward
# step157: action = move_forward
# step158: action = move_forward
# step159: action = move_forward
# step160: action = move_forward
# step161: action = move_forward
# step162: action = move_forward
# step163: action = move_forward
# step164: action = move_forward
# step165: action = move_forward
# step166: action = move_forward
# step167: action = move_forward
# step168: action = move_forward
# step169: action = move_forward
# step170: action = move_forward
# step171: action = move_forward
# step172: action = move_forward
# step173: action = move_forward
# step174: action = move_forward
# step175: action = move_forward
# step176: action = move_forward
# step177: action = move_forward
# step178: action = move_forward
# step179: action = move_forward
# step180: action = move_forward
# step181: action = move_forward
# step182: action = move_forward
# step183: action = move_forward
#
# reach point 1
# step184: action = turn_right
# step185: action = turn_right
# step186: action = turn_right
# step187: action = turn_right
# step188: action = turn_right
# step189: action = turn_right
# step190: action = turn_right
# step191: action = turn_right
# step192: action = turn_right
# step193: action = turn_right
# step194: action = turn_right
# step195: action = turn_right
# step196: action = turn_right
# step197: action = turn_right
# step198: action = turn_right
# step199: action = turn_right
# step200: action = turn_right
# step201: action = turn_right
# step202: action = turn_right
# step203: action = turn_right
# step204: action = turn_right
# step205: action = turn_right
# step206: action = turn_right
# step207: action = turn_right
# step208: action = turn_right
# step209: action = turn_right
# step210: action = turn_right
# step211: action = turn_right
# step212: action = turn_right
# step213: action = turn_right
# step214: action = turn_right
# step215: action = turn_right
# step216: action = turn_right
# step217: action = turn_right
# step218: action = turn_right
# step219: action = turn_right
# step220: action = turn_right
# step221: action = turn_right
# step222: action = turn_right
# step223: action = turn_right
# step224: action = turn_right
# step225: action = turn_right
# step226: action = turn_right
# step227: action = turn_right
# step228: action = turn_right
# step229: action = turn_right
# step230: action = turn_right
# step231: action = turn_right
# step232: action = turn_right
# step233: action = turn_right
# step234: action = turn_right
# step235: action = turn_right
# step236: action = turn_right
# step237: action = turn_right
# step238: action = turn_right
# step239: action = turn_right
# step240: action = turn_right
# step241: action = turn_right
# step242: action = turn_right
# step243: action = turn_right
# step244: action = turn_right
# step245: action = turn_right
# step246: action = turn_right
# step247: action = turn_right
# step248: action = turn_right
# step249: action = turn_right
# step250: action = turn_right
# step251: action = turn_right
# step252: action = turn_right
# step253: action = turn_right
# step254: action = turn_right
# step255: action = turn_right
# step256: action = turn_right
# step257: action = turn_right
# step258: action = turn_right
# step259: action = turn_right
# step260: action = turn_right
# step261: action = turn_right
# step262: action = turn_right
# step263: action = turn_right
# step264: action = turn_right
# step265: action = turn_right
# step266: action = move_forward
# step267: action = move_forward
# step268: action = move_forward
# step269: action = move_forward
# step270: action = move_forward
# step271: action = move_forward
# step272: action = move_forward
# step273: action = move_forward
# step274: action = move_forward
# step275: action = move_forward
# step276: action = move_forward
# step277: action = move_forward
# step278: action = move_forward
# step279: action = move_forward
# step280: action = move_forward
# step281: action = move_forward
# step282: action = move_forward
# step283: action = move_forward
# step284: action = move_forward
# step285: action = move_forward
# step286: action = move_forward
# step287: action = move_forward
# step288: action = move_forward
# step289: action = move_forward
# step290: action = move_forward
# step291: action = move_forward
# step292: action = move_forward
# step293: action = move_forward
# step294: action = move_forward
# step295: action = move_forward
# step296: action = move_forward
# step297: action = move_forward
# step298: action = move_forward
# step299: action = move_forward
# step300: action = move_forward
# step301: action = move_forward
# step302: action = move_forward
# step303: action = move_forward
# step304: action = move_forward
# step305: action = move_forward
# step306: action = move_forward
# step307: action = move_forward
# step308: action = move_forward
# step309: action = move_forward
# step310: action = move_forward
# step311: action = move_forward
# step312: action = move_forward
# step313: action = move_forward
# step314: action = move_forward
# step315: action = move_forward
# step316: action = move_forward
# step317: action = move_forward
# step318: action = move_forward
# step319: action = move_forward
# step320: action = move_forward
# step321: action = move_forward
# step322: action = move_forward
# step323: action = move_forward
# step324: action = move_forward
# step325: action = move_forward
# step326: action = move_forward
# step327: action = move_forward
# step328: action = move_forward
# step329: action = move_forward
# step330: action = move_forward
# step331: action = move_forward
# step332: action = move_forward
# step333: action = move_forward
# step334: action = move_forward
# step335: action = move_forward
# step336: action = move_forward
# step337: action = move_forward
# step338: action = move_forward
# step339: action = move_forward
# step340: action = move_forward
# step341: action = move_forward
# step342: action = move_forward
# step343: action = move_forward
# step344: action = move_forward
# step345: action = move_forward
# step346: action = move_forward
# step347: action = move_forward
# step348: action = move_forward
# step349: action = move_forward
# step350: action = move_forward
# step351: action = move_forward
# step352: action = move_forward
# step353: action = move_forward
# step354: action = move_forward
# step355: action = move_forward
# step356: action = move_forward
# step357: action = move_forward
# step358: action = move_forward
# step359: action = move_forward
# step360: action = move_forward
# step361: action = move_forward
# step362: action = move_forward
# step363: action = move_forward
# step364: action = move_forward
# step365: action = move_forward
# step366: action = move_forward
# step367: action = move_forward
# step368: action = move_forward
# step369: action = move_forward
# step370: action = move_forward
# step371: action = move_forward
# step372: action = move_forward
# step373: action = move_forward
# step374: action = move_forward
# step375: action = move_forward
# step376: action = move_forward
# step377: action = move_forward
# step378: action = move_forward
# step379: action = move_forward
# step380: action = move_forward
# step381: action = move_forward
# step382: action = move_forward
# step383: action = move_forward
# step384: action = move_forward
# step385: action = move_forward
# step386: action = move_forward
# step387: action = move_forward
# step388: action = move_forward
# step389: action = move_forward
# step390: action = move_forward
# step391: action = move_forward
# step392: action = move_forward
# step393: action = move_forward
# step394: action = move_forward
# step395: action = move_forward
# step396: action = move_forward
# step397: action = move_forward
# step398: action = move_forward
# step399: action = move_forward
# step400: action = move_forward
# step401: action = move_forward
# step402: action = move_forward
# step403: action = move_forward
# step404: action = move_forward
# step405: action = move_forward
# step406: action = move_forward
# step407: action = move_forward
# step408: action = move_forward
# step409: action = move_forward
# step410: action = move_forward
# step411: action = move_forward
# step412: action = move_forward
# step413: action = move_forward
# step414: action = move_forward
# step415: action = move_forward
# step416: action = move_forward
# step417: action = move_forward
# step418: action = move_forward
# step419: action = move_forward
# step420: action = move_forward
# step421: action = move_forward
# step422: action = move_forward
# step423: action = move_forward
# step424: action = move_forward
# step425: action = move_forward
# step426: action = move_forward
# step427: action = move_forward
# step428: action = move_forward
# step429: action = move_forward
# step430: action = move_forward
# step431: action = move_forward
# step432: action = move_forward
# step433: action = move_forward
# step434: action = move_forward
# step435: action = move_forward
# step436: action = move_forward
# step437: action = move_forward
# step438: action = move_forward
# step439: action = move_forward
# step440: action = move_forward
# step441: action = move_forward
# step442: action = move_forward
# step443: action = move_forward
# step444: action = move_forward
# step445: action = move_forward
# step446: action = move_forward
# step447: action = move_forward
# step448: action = move_forward
# step449: action = move_forward
# step450: action = move_forward
# step451: action = move_forward
# step452: action = move_forward
# step453: action = move_forward
# step454: action = move_forward
# step455: action = move_forward
# step456: action = move_forward
# step457: action = move_forward
# step458: action = move_forward
# step459: action = move_forward
# step460: action = move_forward
# step461: action = move_forward
# step462: action = move_forward
# step463: action = move_forward
# step464: action = move_forward
# step465: action = move_forward
# step466: action = move_forward
# step467: action = move_forward
# step468: action = move_forward
# step469: action = move_forward
# step470: action = move_forward
# step471: action = move_forward
# step472: action = move_forward
# step473: action = move_forward
# step474: action = move_forward
# step475: action = move_forward
# step476: action = move_forward
# step477: action = move_forward
# step478: action = move_forward
# step479: action = move_forward
# step480: action = move_forward
# step481: action = move_forward
# step482: action = move_forward
# step483: action = move_forward
# step484: action = move_forward
# step485: action = move_forward
# step486: action = move_forward
# step487: action = move_forward
# step488: action = move_forward
# step489: action = move_forward
# step490: action = move_forward
# step491: action = move_forward
# step492: action = move_forward
# step493: action = move_forward
# step494: action = move_forward
# step495: action = move_forward
# step496: action = move_forward
# step497: action = move_forward
# step498: action = move_forward
# step499: action = move_forward
# step500: action = move_forward
# step501: action = move_forward
# step502: action = move_forward
# step503: action = move_forward
# step504: action = move_forward
# step505: action = move_forward
# step506: action = move_forward
# step507: action = move_forward
# step508: action = move_forward
# step509: action = move_forward
# step510: action = move_forward
# step511: action = move_forward
# step512: action = move_forward
# step513: action = move_forward
# step514: action = move_forward
# step515: action = move_forward
# step516: action = move_forward
# step517: action = move_forward
# step518: action = move_forward
# step519: action = move_forward
# step520: action = move_forward
# step521: action = move_forward
# step522: action = move_forward
# step523: action = move_forward
# step524: action = move_forward
# step525: action = move_forward
# step526: action = move_forward
# step527: action = move_forward
# step528: action = move_forward
# step529: action = move_forward
# step530: action = move_forward
# step531: action = move_forward
# step532: action = move_forward
# step533: action = move_forward
# step534: action = move_forward
# step535: action = move_forward
# step536: action = move_forward
# step537: action = move_forward
# step538: action = move_forward
# step539: action = move_forward
# step540: action = move_forward

# %%
img_array = []
filename = dataset_name

size = (0, 0)
img_pth = sorted(glob.glob(f'./trajectory/{filename}/rgb/*.png'))

for cnt, i in enumerate(img_pth):
    img = cv2.imread(i)
    height, width, layers = img.shape
    size = (width, height)
    img_array.append(img)

    if cnt == len(img_pth) - 1:
        for j in range(200):
            img_array.append(img)
 
out = cv2.VideoWriter(f'./trajectory/{filename}/project.mp4', cv2.VideoWriter_fourcc(*'MP4V'), 80, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()
